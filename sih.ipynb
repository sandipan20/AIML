# %%
# !pip install -q kaggle

from dotenv import load_dotenv
import os

load_dotenv()

GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

print(GEMINI_API_KEY is not None)

# !kaggle datasets download -d theprtsh/sih-2025-problem-dataset --unzip
# Out:
# False
# ...
# Dataset URL: https://www.kaggle.com/datasets/theprtsh/sih-2025-problem-dataset
# License(s): GPL-3.0
# ...
# 100% 72.8k/72.8k [00:00<00:00, 419kB/s]

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("sih-2025-ps.csv")

# %%
df.head()
# Out:
#    Category Dataset_Links                                         Department  \
# 0  Software           NaN  Ministry of Health & Family Welfare/Ministry o...
# 1  Software           NaN  Ministry of Tourism/ Ministry of Home Affairs ...
# 2  Hardware           NaN  Ministry of Rural Development/ Ministry of Env...
# 3  Software           NaN  Department of Animal Husbandry & Dairying (DoA...
# 4  Software           NaN  Department of Animal Husbandry & Dairying (DoA...
#
#                                          Description  \
# 0  Problem Statement This problem statement propo...
# 1  Problem Statement This problem statement propo...
# 2  Problem Statement This problem statement propo...
# 3  Background The Government of India is implemen...
# 4  Background: In dairy farming, evaluating the b...
#
#                                         Organization  Problem_Statement_ID  \
# 0    Ministry of Development of North Eastern Region                 25001
# ...

# %%
df.shape
# Out:
# (135, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135 entries, 0 to 134
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Category                 135 non-null    object
#  1   Dataset_Links            5 non-null      object
#  2   Department               135 non-null    object
#  3   Description              135 non-null    object
#  4   Organization             135 non-null    object
#  5   Problem_Statement_ID     135 non-null    int64
#  6   Problem_Statement_Title  135 non-null    object
#  7   Theme                    135 non-null    object
#  8   Youtube_Links            5 non-null      object
# dtypes: int64(1), object(8)
# memory usage: 9.6+ KB

# %%
#removing the row with category as "Hardware" as it is not required for our analysis
df = df[df['Category'] != 'Hardware']

# %%
df.sample(5)
# Out:
#      Category Dataset_Links                                    Department  \
# 87   Software           NaN                   Higher Education Department
# 27   Software           NaN  Department of Higher and Technical Education
# 97   Software           NaN      Directorate of Technical Education (DTE)
# 119  Software           NaN                 AICTE, MIC-Student Innovation
# 75   Software           NaN                     Department of Agriculture
#
#                                            Description  \
# 87   Background: Despite increasing digitization in...
# 27   Background Higher Education institutions often...
# 97   Background: Admissions, fee collection, hostel...
# 119  Provide ideas in a decentralized and distribut...
# 75   Problem Farmers often face critical questions ...
#
#                         Organization  Problem_Statement_ID  \
# 87   Government of Jammu and Kashmir                 25093
# 27           Government of Jharkhand                 25028
# ...

# %%
df.shape
# Out:
# (90, 9)

# %%
df[df['Theme'].isin([
    'Heritage & Culture',
    'Blockchain & Cybersecurity'
])]
# Out:
#      Category Dataset_Links                              Department  \
# 26   Software           NaN  All India Institute of Ayurveda (AIIA)
# 51   Software           NaN             Electronics & IT Department
# 99   Software           NaN          Indian Knowledge Systems (IKS)
# 119  Software           NaN           AICTE, MIC-Student Innovation
# 122  Software           NaN           AICTE, MIC-Student Innovation
#
#                                            Description          Organization  \
# 26   Background The Ayurvedic herbal supply chain i...     Ministry of Ayush
# 51   Description Create an augmented reality (AR) p...  Government of Odisha
# 99   Kolams (known by other narnes as muggu, rangol...                 AICTE
# 119  Provide ideas in a decentralized and distribut...                 AICTE
# 122  Ideas that showcase the rich cultural heritage...                 AICTE
#
#      Problem_Statement_ID                            Problem_Statement_Title  \
# ...

# %%
df = df[~df['Theme'].isin([
    'Blockchain & Cybersecurity',
    'Heritage & Culture'
])]

# %%
df.shape
# Out:
# (85, 9)

# %%
df.to_csv('/content/final_dataframe.csv', index=False)
