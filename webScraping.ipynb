# %%
import pandas as pd
import requests as rq
from bs4 import BeautifulSoup as bs

# %%
headers = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/138.0.0.0 Safari/537.36"
    )
}
webpage=rq.get('https://www.du.ac.in/index.php?page=colleges-at-du$0', headers=headers).text

# %%
soup=bs(webpage,'html')
# soup

# %%
college=[]
for i in soup.find_all('a',rel="noopener"):
  college.append(i.text.strip())
data=pd.DataFrame({'college':college})
data.reset_index(drop=True,inplace=True)

# %%
data
# Out:
#                                               college
# 0        Department of Finance and Business Economics
# 1                              Department of Commerce
# 2                             Department of Education
# 3                                   Department of Law
# 4                                Department of Arabic
# ..                                                ...
# 75                           Department of Physiology
# 76                           Department of Psychiatry
# 77                   Department of Pulmonary Medicine
# 78  Department of Radiology, Radiotherapy, Radiodi...
# 79                              Department of Surgery
#
# [80 rows x 1 columns]
